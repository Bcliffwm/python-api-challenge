# %%
import pandas as pd

# %%
pd.read_excel("variable_declarations_final_draft_jhs3June_.xlsx", error_bad_lines=False)
# Out:
#     item               modules               functions                tab  \
# 0      1     input array sizes                     NaN  input array sizes
# 1      2        SelectRFbandV1                     NaN       SelectRFband
# 2      3                   NaN                  unwrap       SelectRFband
# 3      4  MUSignalCollectionV2                     NaN                NaN
# 4      5                   NaN  MUSignalgenerator_ExV1                NaN
# ..   ...                   ...                     ...                ...
# 70    72                   NaN                   EQUv2                NaN
# 71    73                   NaN                npultest                NaN
# 72    74                   NaN             ScoreSimpEQ                NaN
# 73    75                   NaN               ScoreEQv4                NaN
# 74    76                   NaN             Calpritest1                NaN
#
#    Completed   loc  # variables
# 0        yes   NaN          NaN
# ...

# %%
df_clean = pd.read_excel('variable_declarations_final_draft_jhs3June_.xlsx',
                 lineterminator='\n')

# %%
df_clean
# Out:
#     item               modules               functions                tab  \
# 0      1     input array sizes                     NaN  input array sizes
# 1      2        SelectRFbandV1                     NaN       SelectRFband
# 2      3                   NaN                  unwrap       SelectRFband
# 3      4  MUSignalCollectionV2                     NaN                NaN
# 4      5                   NaN  MUSignalgenerator_ExV1                NaN
# ..   ...                   ...                     ...                ...
# 70    72                   NaN                   EQUv2                NaN
# 71    73                   NaN                npultest                NaN
# 72    74                   NaN             ScoreSimpEQ                NaN
# 73    75                   NaN               ScoreEQv4                NaN
# 74    76                   NaN             Calpritest1                NaN
#
#    Completed   loc  # variables
# 0        yes   NaN          NaN
# ...

# %%
import pandas as pd

# %%
converting_df = pd.read_csv('MOAtestFile.txt')
converting_df
# Out:
#     evaluation instances  total train time  total train speed  \
# 0                10000.0          0.093750      106666.666667
# 1                20000.0          0.140625      142222.222222
# 2                30000.0          0.171875      174545.454545
# 3                40000.0          0.218750      182857.142857
# 4                50000.0          0.265625      188235.294118
# ..                   ...               ...                ...
# 95              960000.0          4.062500      236307.692308
# 96              970000.0          4.109375      236045.627376
# 97              980000.0          4.156250      235789.473684
# 98              990000.0          4.203125      235539.033457
# 99             1000000.0          4.437500      225352.112676
#
#     last train time  last train speed  test time  test speed  \
# 0          0.093750     106666.666667        0.0         inf
# 1          0.046875     213333.333333        0.0         inf
# ...

# %%
converting_df.to_csv("MOAtest")

# %%
pd.read_csv("MOAtest")
# Out:
#     Unnamed: 0  evaluation instances  total train time  total train speed  \
# 0            0               10000.0          0.093750      106666.666667
# 1            1               20000.0          0.140625      142222.222222
# 2            2               30000.0          0.171875      174545.454545
# 3            3               40000.0          0.218750      182857.142857
# 4            4               50000.0          0.265625      188235.294118
# ..         ...                   ...               ...                ...
# 95          95              960000.0          4.062500      236307.692308
# 96          96              970000.0          4.109375      236045.627376
# 97          97              980000.0          4.156250      235789.473684
# 98          98              990000.0          4.203125      235539.033457
# 99          99             1000000.0          4.437500      225352.112676
#
#     last train time  last train speed  test time  test speed  \
# ...
